# %% [markdown]
# Converte para SRT

# %%
import re
from datetime import timedelta, datetime

# Entrada de dados
dados = '''
(0:20) Itadori: "Com tudo, sem hesitar!" 
(0:24) Nobara: "Tô um caco, mas quem liga?"
(0:32) Megumi: "Estratégia justa... nada mal."
(0:38) Maki: "Sem vacilar agora, corre!"
(0:42) Toge: "Salmon."
(0:44) Gojo: "Brincar com a vovó, parece divertido."
(1:02) Itadori: "Não tava assustado! Talvez um pouco."
(1:11) Nobara: "Enorme? Só uma velha insignificante."
(1:15) Megumi: "Mantenha a calma, sem pânico."
(1:23) Maki: "Hora de fugir. Sem pensar duas vezes."
(1:30) Toge: "Mostarda."
(1:38) Gojo: "Confio, mostre do que é capaz."
(1:47) Itadori: "Não sei se consigo, mas vou tentar!"
(2:02) Nobara: "Sério? Não acredito que deu certo."
(2:06) Megumi: "Algo está errado, não vejo a maldição."
(2:15) Maki: "Não podemos baixar a guarda agora."
(2:21) Toge: "Kelp."
(2:32) Gojo: "Provoca ele, ele vai cair."
(2:42) Itadori: "Isso, mostre sua velocidade, vovó!"
(3:02) Nobara: "Acha que pode me desafiar?"
(3:13) Megumi: "Vamos brincar de pega-pega, é isso."
(3:25) Maki: "Essas são as regras, siga-as."
(3:47) Toge: "Atum."
(4:00) Gojo: "Contou errado! Que graça."
(4:12) Itadori: "Ayase, aguenta aí!"
(4:25) Nobara: "Isso é trapaça, não vale!"
(4:33) Megumi: "Prometeu seguir as regras."
(4:38) Maki: "Chega dessa palhaçada!"
(4:46) Toge: "Maionese."
(5:01) Gojo: "Garoto, segura firme aí."
(5:15) Itadori: "A purificação funcionou? Ainda não acredito."
(5:34) Nobara: "Tá em contato com xamãs? Patético."
(5:45) Megumi: "Essa sensação... algo estranho."
(6:03) Maki: "Não vou soltar fácil."
(6:17) Toge: "Bonito."
(6:20) Gojo: "Bom trabalho, continuem pressionando."
(6:35) Itadori: "Não subestime o poder da amizade!"
(7:20) Nobara: "Trapaceiros nunca ganham, sabia?"
(7:37) Megumi: "Como torturar você agora?"
(7:53) Maki: "Precisamos ser rápidos."
(8:33) Toge: "Sushi."
(8:38) Gojo: "Transforme-se, faça valer."
(8:54) Itadori: "Ufa, que sorte!"
(9:06) Nobara: "Não grita meu nome!"
(9:22) Megumi: "Parece um tornado, está sério."
(9:36) Maki: "Já deu, vamos recuar."
(9:52) Toge: "Wakame."
(10:02) Gojo: "Cena engraçada, ninguém está vendo?"
(10:16) Itadori: "Vamos lá, escapar juntos!"
(10:35) Nobara: "Dois, por favor. Rápido!"
(10:55) Megumi: "Cuidado, ele está na vantagem."
(11:11) Maki: "Caranguejos ficam firmes cozidos, certo?"
(11:27) Toge: "Bonito."
(11:34) Gojo: "Não olhe para trás, siga em frente." 
(11:51) Itadori: "O que é aquilo? Mais problemas?"
(12:00) Nobara: "Acham que vamos facilitar?"
(12:23) Megumi: "Ayase! Não desista!"
(12:42) Maki: "Se não tentarmos, morreremos aqui."
(13:06) Toge: "Pimenta."
(15:07) Gojo: "No limite? Ainda tem chão."
(15:15) Itadori: "Quase lá! Só mais um pouco!"
(15:32) Nobara: "Isso é falta de respeito!"
(16:01) Megumi: "Caiu na armadilha."
(16:18) Maki: "Vamos ver se alcançam."
(17:07) Toge: "Mostarda."
(17:32) Gojo: "Bem-vindo ao inferno!" 
(18:34) Itadori: "Ayase, onde estamos?"
(18:49) Nobara: "Elas não mereciam esse destino." 
(19:16) Megumi: "Tentando confortar as almas."
(19:40) Maki: "Nunca desrespeite os mortos."
(19:51) Toge: "Umeboshi."
(20:16) Gojo: "Este lugar é mais seguro, confiem." 
(21:13) Itadori: "Não vou mostrar nada, esqueça."
(21:29) Nobara: "Desculpa, não queria causar."
(21:42) Megumi: "Adeus, até breve."
'''

import re
from datetime import timedelta, datetime

# Parseia os dados
entries = []
pattern = r'\((\d+):(\d+)\)\s*(.+?):\s*"(.+?)"'

matches = re.findall(pattern, dados)

for match in matches:
    minuto = int(match[0])
    segundo = int(match[1])
    timestamp = timedelta(minutes=minuto, seconds=segundo)
    personagem = match[2]
    fala = match[3]
    entries.append({
        'timestamp': timestamp,
        'personagem': personagem,
        'fala': fala
    })

# Calcula os tempos de término
for i in range(len(entries)):
    inicio = entries[i]['timestamp']
    if i < len(entries) - 1:
        proximo_inicio = entries[i+1]['timestamp']
        # Subtrai 0.5 segundos para evitar sobreposição
        fim = proximo_inicio - timedelta(seconds=0.5)
        # Garante que o tempo final é após o inicial
        if fim <= inicio:
            fim = inicio + timedelta(seconds=2)
    else:
        # Última legenda, adiciona 2 segundos
        fim = inicio + timedelta(seconds=2)
    entries[i]['fim'] = fim

# Escreve o arquivo .srt
with open('legendas.srt', 'w', encoding='utf-8') as f:
    for i, entry in enumerate(entries):
        f.write(f"{i+1}\n")
        inicio_formatado = (datetime.min + entry['timestamp']).strftime('%H:%M:%S,%f')[:-3]
        fim_formatado = (datetime.min + entry['fim']).strftime('%H:%M:%S,%f')[:-3]
        f.write(f"{inicio_formatado} --> {fim_formatado}\n")
        f.write(f"{entry['personagem']}: \"{entry['fala']}\"\n\n")

# %% [markdown]
# Converte para a cada 5s uma fala

# %%
import re
from datetime import timedelta, datetime

# Entrada de dados
dados = '''
(0:20) Itadori: "Com tudo, sem hesitar!" 
(0:24) Nobara: "Tô um caco, mas quem liga?"
(0:32) Megumi: "Estratégia justa... nada mal."
(0:38) Maki: "Sem vacilar agora, corre!"
(0:42) Toge: "Salmon."
(0:44) Gojo: "Brincar com a vovó, parece divertido."
(1:02) Itadori: "Não tava assustado! Talvez um pouco."
(1:11) Nobara: "Enorme? Só uma velha insignificante."
(1:15) Megumi: "Mantenha a calma, sem pânico."
(1:23) Maki: "Hora de fugir. Sem pensar duas vezes."
(1:30) Toge: "Mostarda."
(1:38) Gojo: "Confio, mostre do que é capaz."
(1:47) Itadori: "Não sei se consigo, mas vou tentar!"
(2:02) Nobara: "Sério? Não acredito que deu certo."
(2:06) Megumi: "Algo está errado, não vejo a maldição."
(2:15) Maki: "Não podemos baixar a guarda agora."
(2:21) Toge: "Kelp."
(2:32) Gojo: "Provoca ele, ele vai cair."
(2:42) Itadori: "Isso, mostre sua velocidade, vovó!"
(3:02) Nobara: "Acha que pode me desafiar?"
(3:13) Megumi: "Vamos brincar de pega-pega, é isso."
(3:25) Maki: "Essas são as regras, siga-as."
(3:47) Toge: "Atum."
(4:00) Gojo: "Contou errado! Que graça."
(4:12) Itadori: "Ayase, aguenta aí!"
(4:25) Nobara: "Isso é trapaça, não vale!"
(4:33) Megumi: "Prometeu seguir as regras."
(4:38) Maki: "Chega dessa palhaçada!"
(4:46) Toge: "Maionese."
(5:01) Gojo: "Garoto, segura firme aí."
(5:15) Itadori: "A purificação funcionou? Ainda não acredito."
(5:34) Nobara: "Tá em contato com xamãs? Patético."
(5:45) Megumi: "Essa sensação... algo estranho."
(6:03) Maki: "Não vou soltar fácil."
(6:17) Toge: "Bonito."
(6:20) Gojo: "Bom trabalho, continuem pressionando."
(6:35) Itadori: "Não subestime o poder da amizade!"
(7:20) Nobara: "Trapaceiros nunca ganham, sabia?"
(7:37) Megumi: "Como torturar você agora?"
(7:53) Maki: "Precisamos ser rápidos."
(8:33) Toge: "Sushi."
(8:38) Gojo: "Transforme-se, faça valer."
(8:54) Itadori: "Ufa, que sorte!"
(9:06) Nobara: "Não grita meu nome!"
(9:22) Megumi: "Parece um tornado, está sério."
(9:36) Maki: "Já deu, vamos recuar."
(9:52) Toge: "Wakame."
(10:02) Gojo: "Cena engraçada, ninguém está vendo?"
(10:16) Itadori: "Vamos lá, escapar juntos!"
(10:35) Nobara: "Dois, por favor. Rápido!"
(10:55) Megumi: "Cuidado, ele está na vantagem."
(11:11) Maki: "Caranguejos ficam firmes cozidos, certo?"
(11:27) Toge: "Bonito."
(11:34) Gojo: "Não olhe para trás, siga em frente." 
(11:51) Itadori: "O que é aquilo? Mais problemas?"
(12:00) Nobara: "Acham que vamos facilitar?"
(12:23) Megumi: "Ayase! Não desista!"
(12:42) Maki: "Se não tentarmos, morreremos aqui."
(13:06) Toge: "Pimenta."
(15:07) Gojo: "No limite? Ainda tem chão."
(15:15) Itadori: "Quase lá! Só mais um pouco!"
(15:32) Nobara: "Isso é falta de respeito!"
(16:01) Megumi: "Caiu na armadilha."
(16:18) Maki: "Vamos ver se alcançam."
(17:07) Toge: "Mostarda."
(17:32) Gojo: "Bem-vindo ao inferno!" 
(18:34) Itadori: "Ayase, onde estamos?"
(18:49) Nobara: "Elas não mereciam esse destino." 
(19:16) Megumi: "Tentando confortar as almas."
(19:40) Maki: "Nunca desrespeite os mortos."
(19:51) Toge: "Umeboshi."
(20:16) Gojo: "Este lugar é mais seguro, confiem." 
(21:13) Itadori: "Não vou mostrar nada, esqueça."
(21:29) Nobara: "Desculpa, não queria causar."
(21:42) Megumi: "Adeus, até breve."
'''

import re
from datetime import timedelta, datetime

# Parseia os dados
entries = []
pattern = r'\((\d+):(\d+)\)\s*(.+?):\s*"(.+?)"'

matches = re.findall(pattern, dados)

for match in matches:
    minuto = int(match[0])
    segundo = int(match[1])
    timestamp = timedelta(minutes=minuto, seconds=segundo)
    personagem = match[2]
    fala = match[3]
    entries.append({
        'timestamp': timestamp,
        'personagem': personagem,
        'fala': fala
    })

# Duração total do vídeo (timestamp da última fala + 5 segundos)
duracao_total = entries[-1]['timestamp'] + timedelta(seconds=5)
# Número total de falas
num_falas = len(entries)
# Calcula o intervalo entre as falas
intervalo_falas = duracao_total / num_falas

# Agenda as falas ao longo do vídeo
for i, entry in enumerate(entries):
    inicio = intervalo_falas * i
    # Ajusta o início para o múltiplo de 5 segundos mais próximo (para baixo)
    total_seconds = int(inicio.total_seconds())
    inicio_seconds = (total_seconds // 5) * 5
    inicio = timedelta(seconds=inicio_seconds)
    fim = inicio + timedelta(seconds=5)
    entry['inicio'] = inicio
    entry['fim'] = fim

# Escreve o arquivo .srt
with open('legendas.srt', 'w', encoding='utf-8') as f:
    for i, entry in enumerate(entries):
        f.write(f"{i+1}\n")
        inicio_formatado = (datetime.min + entry['inicio']).strftime('%H:%M:%S,%f')[:-3]
        fim_formatado = (datetime.min + entry['fim']).strftime('%H:%M:%S,%f')[:-3]
        f.write(f"{inicio_formatado} --> {fim_formatado}\n")
        f.write(f"{entry['personagem']}: \"{entry['fala']}\"\n\n")

# %%
import re
from datetime import timedelta, datetime

# Entrada de dados
dados = '''
(0:20) Itadori: "Com tudo, sem hesitar!" 
(0:24) Nobara: "Tô um caco, mas quem liga?"
(0:32) Megumi: "Estratégia justa... nada mal."
(0:38) Maki: "Sem vacilar agora, corre!"
(0:42) Toge: "Salmon."
(0:44) Gojo: "Brincar com a vovó, parece divertido."
(1:02) Itadori: "Não tava assustado! Talvez um pouco."
(1:11) Nobara: "Enorme? Só uma velha insignificante."
(1:15) Megumi: "Mantenha a calma, sem pânico."
(1:23) Maki: "Hora de fugir. Sem pensar duas vezes."
(1:30) Toge: "Mostarda."
(1:38) Gojo: "Confio, mostre do que é capaz."
(1:47) Itadori: "Não sei se consigo, mas vou tentar!"
(2:02) Nobara: "Sério? Não acredito que deu certo."
(2:06) Megumi: "Algo está errado, não vejo a maldição."
(2:15) Maki: "Não podemos baixar a guarda agora."
(2:21) Toge: "Kelp."
(2:32) Gojo: "Provoca ele, ele vai cair."
(2:42) Itadori: "Isso, mostre sua velocidade, vovó!"
(3:02) Nobara: "Acha que pode me desafiar?"
(3:13) Megumi: "Vamos brincar de pega-pega, é isso."
(3:25) Maki: "Essas são as regras, siga-as."
(3:47) Toge: "Atum."
(4:00) Gojo: "Contou errado! Que graça."
(4:12) Itadori: "Ayase, aguenta aí!"
(4:25) Nobara: "Isso é trapaça, não vale!"
(4:33) Megumi: "Prometeu seguir as regras."
(4:38) Maki: "Chega dessa palhaçada!"
(4:46) Toge: "Maionese."
(5:01) Gojo: "Garoto, segura firme aí."
(5:15) Itadori: "A purificação funcionou? Ainda não acredito."
(5:34) Nobara: "Tá em contato com xamãs? Patético."
(5:45) Megumi: "Essa sensação... algo estranho."
(6:03) Maki: "Não vou soltar fácil."
(6:17) Toge: "Bonito."
(6:20) Gojo: "Bom trabalho, continuem pressionando."
(6:35) Itadori: "Não subestime o poder da amizade!"
(7:20) Nobara: "Trapaceiros nunca ganham, sabia?"
(7:37) Megumi: "Como torturar você agora?"
(7:53) Maki: "Precisamos ser rápidos."
(8:33) Toge: "Sushi."
(8:38) Gojo: "Transforme-se, faça valer."
(8:54) Itadori: "Ufa, que sorte!"
(9:06) Nobara: "Não grita meu nome!"
(9:22) Megumi: "Parece um tornado, está sério."
(9:36) Maki: "Já deu, vamos recuar."
(9:52) Toge: "Wakame."
(10:02) Gojo: "Cena engraçada, ninguém está vendo?"
(10:16) Itadori: "Vamos lá, escapar juntos!"
(10:35) Nobara: "Dois, por favor. Rápido!"
(10:55) Megumi: "Cuidado, ele está na vantagem."
(11:11) Maki: "Caranguejos ficam firmes cozidos, certo?"
(11:27) Toge: "Bonito."
(11:34) Gojo: "Não olhe para trás, siga em frente." 
(11:51) Itadori: "O que é aquilo? Mais problemas?"
(12:00) Nobara: "Acham que vamos facilitar?"
(12:23) Megumi: "Ayase! Não desista!"
(12:42) Maki: "Se não tentarmos, morreremos aqui."
(13:06) Toge: "Pimenta."
(15:07) Gojo: "No limite? Ainda tem chão."
(15:15) Itadori: "Quase lá! Só mais um pouco!"
(15:32) Nobara: "Isso é falta de respeito!"
(16:01) Megumi: "Caiu na armadilha."
(16:18) Maki: "Vamos ver se alcançam."
(17:07) Toge: "Mostarda."
(17:32) Gojo: "Bem-vindo ao inferno!" 
(18:34) Itadori: "Ayase, onde estamos?"
(18:49) Nobara: "Elas não mereciam esse destino." 
(19:16) Megumi: "Tentando confortar as almas."
(19:40) Maki: "Nunca desrespeite os mortos."
(19:51) Toge: "Umeboshi."
(20:16) Gojo: "Este lugar é mais seguro, confiem." 
(21:13) Itadori: "Não vou mostrar nada, esqueça."
(21:29) Nobara: "Desculpa, não queria causar."
(21:42) Megumi: "Adeus, até breve."
'''

import re
from datetime import timedelta, datetime

# Parseia os dados
entries = []
pattern = r'\((\d+):(\d+)\)\s*(.+?):\s*"(.+?)"'

matches = re.findall(pattern, dados)

for match in matches:
    minuto = int(match[0])
    segundo = int(match[1])
    timestamp = timedelta(minutes=minuto, seconds=segundo)
    personagem = match[2]
    fala = match[3]
    entries.append({
        'timestamp': timestamp,
        'personagem': personagem,
        'fala': fala
    })

# Calcula os tempos de término
for i in range(len(entries)):
    inicio = entries[i]['timestamp']
    if i < len(entries) - 1:
        proximo_inicio = entries[i+1]['timestamp']
        # Subtrai 0.5 segundos para evitar sobreposição
        fim = proximo_inicio - timedelta(seconds=0.5)
        # Garante que o tempo final é após o inicial
        if fim <= inicio:
            fim = inicio + timedelta(seconds=2)
    else:
        # Última legenda, adiciona 5 segundos
        fim = inicio + timedelta(seconds=5)
    entries[i]['fim'] = fim

# Escreve o arquivo .srt
with open('legendas.srt', 'w', encoding='utf-8') as f:
    for i, entry in enumerate(entries):
        f.write(f"{i+1}\n")
        inicio_formatado = (datetime.min + entry['timestamp']).strftime('%H:%M:%S,%f')[:-3]
        fim_formatado = (datetime.min + entry['fim']).strftime('%H:%M:%S,%f')[:-3]
        f.write(f"{inicio_formatado} --> {fim_formatado}\n")
        f.write(f"{entry['personagem']}: \"{entry['fala']}\"\n\n")

# %%
import re
from datetime import timedelta, datetime

# Entrada de dados
dados = '''
(0:20) Itadori: "Com tudo, sem hesitar!" 
(0:24) Nobara: "Tô um caco, mas quem liga?"
(0:32) Megumi: "Estratégia justa... nada mal."
(0:38) Maki: "Sem vacilar agora, corre!"
(0:42) Toge: "Salmon."
(0:44) Gojo: "Brincar com a vovó, parece divertido."
(1:02) Itadori: "Não tava assustado! Talvez um pouco."
(1:11) Nobara: "Enorme? Só uma velha insignificante."
(1:15) Megumi: "Mantenha a calma, sem pânico."
(1:23) Maki: "Hora de fugir. Sem pensar duas vezes."
(1:30) Toge: "Mostarda."
(1:38) Gojo: "Confio, mostre do que é capaz."
(1:47) Itadori: "Não sei se consigo, mas vou tentar!"
(2:02) Nobara: "Sério? Não acredito que deu certo."
(2:06) Megumi: "Algo está errado, não vejo a maldição."
(2:15) Maki: "Não podemos baixar a guarda agora."
(2:21) Toge: "Kelp."
(2:32) Gojo: "Provoca ele, ele vai cair."
(2:42) Itadori: "Isso, mostre sua velocidade, vovó!"
(3:02) Nobara: "Acha que pode me desafiar?"
(3:13) Megumi: "Vamos brincar de pega-pega, é isso."
(3:25) Maki: "Essas são as regras, siga-as."
(3:47) Toge: "Atum."
(4:00) Gojo: "Contou errado! Que graça."
(4:12) Itadori: "Ayase, aguenta aí!"
(4:25) Nobara: "Isso é trapaça, não vale!"
(4:33) Megumi: "Prometeu seguir as regras."
(4:38) Maki: "Chega dessa palhaçada!"
(4:46) Toge: "Maionese."
(5:01) Gojo: "Garoto, segura firme aí."
(5:15) Itadori: "A purificação funcionou? Ainda não acredito."
(5:34) Nobara: "Tá em contato com xamãs? Patético."
(5:45) Megumi: "Essa sensação... algo estranho."
(6:03) Maki: "Não vou soltar fácil."
(6:17) Toge: "Bonito."
(6:20) Gojo: "Bom trabalho, continuem pressionando."
(6:35) Itadori: "Não subestime o poder da amizade!"
(7:20) Nobara: "Trapaceiros nunca ganham, sabia?"
(7:37) Megumi: "Como torturar você agora?"
(7:53) Maki: "Precisamos ser rápidos."
(8:33) Toge: "Sushi."
(8:38) Gojo: "Transforme-se, faça valer."
(8:54) Itadori: "Ufa, que sorte!"
(9:06) Nobara: "Não grita meu nome!"
(9:22) Megumi: "Parece um tornado, está sério."
(9:36) Maki: "Já deu, vamos recuar."
(9:52) Toge: "Wakame."
(10:02) Gojo: "Cena engraçada, ninguém está vendo?"
(10:16) Itadori: "Vamos lá, escapar juntos!"
(10:35) Nobara: "Dois, por favor. Rápido!"
(10:55) Megumi: "Cuidado, ele está na vantagem."
(11:11) Maki: "Caranguejos ficam firmes cozidos, certo?"
(11:27) Toge: "Bonito."
(11:34) Gojo: "Não olhe para trás, siga em frente." 
(11:51) Itadori: "O que é aquilo? Mais problemas?"
(12:00) Nobara: "Acham que vamos facilitar?"
(12:23) Megumi: "Ayase! Não desista!"
(12:42) Maki: "Se não tentarmos, morreremos aqui."
(13:06) Toge: "Pimenta."
(15:07) Gojo: "No limite? Ainda tem chão."
(15:15) Itadori: "Quase lá! Só mais um pouco!"
(15:32) Nobara: "Isso é falta de respeito!"
(16:01) Megumi: "Caiu na armadilha."
(16:18) Maki: "Vamos ver se alcançam."
(17:07) Toge: "Mostarda."
(17:32) Gojo: "Bem-vindo ao inferno!" 
(18:34) Itadori: "Ayase, onde estamos?"
(18:49) Nobara: "Elas não mereciam esse destino." 
(19:16) Megumi: "Tentando confortar as almas."
(19:40) Maki: "Nunca desrespeite os mortos."
(19:51) Toge: "Umeboshi."
(20:16) Gojo: "Este lugar é mais seguro, confiem." 
(21:13) Itadori: "Não vou mostrar nada, esqueça."
(21:29) Nobara: "Desculpa, não queria causar."
(21:42) Megumi: "Adeus, até breve."
'''

import re
from datetime import timedelta, datetime

# Parseia os dados
entries = []
pattern = r'\((\d+):(\d+)\)\s*(.+?):\s*"(.+?)"'

matches = re.findall(pattern, dados)

for match in matches:
    minuto = int(match[0])
    segundo = int(match[1])
    timestamp = timedelta(minutes=minuto, seconds=segundo)
    personagem = match[2]
    fala = match[3]
    entries.append({
        'timestamp': timestamp,
        'personagem': personagem,
        'fala': fala
    })

# Obtém o tempo total
tempo_total = entries[-1]['timestamp'] + timedelta(seconds=5)

# Gera intervalos de 5 segundos
intervalos = []
tempo_atual = timedelta(seconds=0)
while tempo_atual <= tempo_total:
    intervalos.append(tempo_atual)
    tempo_atual += timedelta(seconds=5)

# Cria um dicionário para armazenar a última fala de cada personagem
ultimas_falas = {}

# Escreve o arquivo .srt
with open('legendas.srt', 'w', encoding='utf-8') as f:
    for i in range(len(intervalos)-1):
        inicio = intervalos[i]
        fim = intervalos[i+1] - timedelta(milliseconds=1)  # Evita sobreposição
        
        # Atualiza as últimas falas dos personagens até este intervalo
        for entry in entries:
            if entry['timestamp'] <= inicio:
                ultimas_falas[entry['personagem']] = entry['fala']
            else:
                break  # As entradas estão em ordem, pode interromper
        
        # Se houver pelo menos uma fala, escreva no arquivo
        if ultimas_falas:
            f.write(f"{i+1}\n")
            inicio_formatado = (datetime.min + inicio).strftime('%H:%M:%S,%f')[:-3]
            fim_formatado = (datetime.min + fim).strftime('%H:%M:%S,%f')[:-3]
            f.write(f"{inicio_formatado} --> {fim_formatado}\n")
            
            # Escreve as falas dos personagens
            for personagem, fala in ultimas_falas.items():
                f.write(f"{personagem}: \"{fala}\"\n")
            f.write("\n")

# %% [markdown]
# converte para txt

# %%
import re

# Entrada de dados
dados = '''
(0:20) Itadori: "Com tudo, sem hesitar!" 
(0:24) Nobara: "Tô um caco, mas quem liga?"
(0:32) Megumi: "Estratégia justa... nada mal."
(0:38) Maki: "Sem vacilar agora, corre!"
(0:42) Toge: "Salmon."
(0:44) Gojo: "Brincar com a vovó, parece divertido."
(1:02) Itadori: "Não tava assustado! Talvez um pouco."
(1:11) Nobara: "Enorme? Só uma velha insignificante."
(1:15) Megumi: "Mantenha a calma, sem pânico."
(1:23) Maki: "Hora de fugir. Sem pensar duas vezes."
(1:30) Toge: "Mostarda."
(1:38) Gojo: "Confio, mostre do que é capaz."
(1:47) Itadori: "Não sei se consigo, mas vou tentar!"
(2:02) Nobara: "Sério? Não acredito que deu certo."
(2:06) Megumi: "Algo está errado, não vejo a maldição."
(2:15) Maki: "Não podemos baixar a guarda agora."
(2:21) Toge: "Kelp."
(2:32) Gojo: "Provoca ele, ele vai cair."
(2:42) Itadori: "Isso, mostre sua velocidade, vovó!"
(3:02) Nobara: "Acha que pode me desafiar?"
(3:13) Megumi: "Vamos brincar de pega-pega, é isso."
(3:25) Maki: "Essas são as regras, siga-as."
(3:47) Toge: "Atum."
(4:00) Gojo: "Contou errado! Que graça."
(4:12) Itadori: "Ayase, aguenta aí!"
(4:25) Nobara: "Isso é trapaça, não vale!"
(4:33) Megumi: "Prometeu seguir as regras."
(4:38) Maki: "Chega dessa palhaçada!"
(4:46) Toge: "Maionese."
(5:01) Gojo: "Garoto, segura firme aí."
(5:15) Itadori: "A purificação funcionou? Ainda não acredito."
(5:34) Nobara: "Tá em contato com xamãs? Patético."
(5:45) Megumi: "Essa sensação... algo estranho."
(6:03) Maki: "Não vou soltar fácil."
(6:17) Toge: "Bonito."
(6:20) Gojo: "Bom trabalho, continuem pressionando."
(6:35) Itadori: "Não subestime o poder da amizade!"
(7:20) Nobara: "Trapaceiros nunca ganham, sabia?"
(7:37) Megumi: "Como torturar você agora?"
(7:53) Maki: "Precisamos ser rápidos."
(8:33) Toge: "Sushi."
(8:38) Gojo: "Transforme-se, faça valer."
(8:54) Itadori: "Ufa, que sorte!"
(9:06) Nobara: "Não grita meu nome!"
(9:22) Megumi: "Parece um tornado, está sério."
(9:36) Maki: "Já deu, vamos recuar."
(9:52) Toge: "Wakame."
(10:02) Gojo: "Cena engraçada, ninguém está vendo?"
(10:16) Itadori: "Vamos lá, escapar juntos!"
(10:35) Nobara: "Dois, por favor. Rápido!"
(10:55) Megumi: "Cuidado, ele está na vantagem."
(11:11) Maki: "Caranguejos ficam firmes cozidos, certo?"
(11:27) Toge: "Bonito."
(11:34) Gojo: "Não olhe para trás, siga em frente." 
(11:51) Itadori: "O que é aquilo? Mais problemas?"
(12:00) Nobara: "Acham que vamos facilitar?"
(12:23) Megumi: "Ayase! Não desista!"
(12:42) Maki: "Se não tentarmos, morreremos aqui."
(13:06) Toge: "Pimenta."
(15:07) Gojo: "No limite? Ainda tem chão."
(15:15) Itadori: "Quase lá! Só mais um pouco!"
(15:32) Nobara: "Isso é falta de respeito!"
(16:01) Megumi: "Caiu na armadilha."
(16:18) Maki: "Vamos ver se alcançam."
(17:07) Toge: "Mostarda."
(17:32) Gojo: "Bem-vindo ao inferno!" 
(18:34) Itadori: "Ayase, onde estamos?"
(18:49) Nobara: "Elas não mereciam esse destino." 
(19:16) Megumi: "Tentando confortar as almas."
(19:40) Maki: "Nunca desrespeite os mortos."
(19:51) Toge: "Umeboshi."
(20:16) Gojo: "Este lugar é mais seguro, confiem." 
(21:13) Itadori: "Não vou mostrar nada, esqueça."
(21:29) Nobara: "Desculpa, não queria causar."
(21:42) Megumi: "Adeus, até breve."
'''

# Lista de emoções possíveis
emocoes = ['feliz', 'neutro', 'triste', 'surpreso']

# Função simples para determinar a emoção com base em palavras-chave
def determinar_emocao(fala):
    fala_lower = fala.lower()
    if any(palavra in fala_lower for palavra in ['!', 'ótimo', 'incrível', 'demais', 'sorte', 'ufa', 'bom trabalho', 'confio']):
        return 'feliz'
    elif any(palavra in fala_lower for palavra in ['não', 'triste', 'patético', 'assustado', 'erro', 'errado', 'problemas', 'palhaçada', 'desrespeito', 'morreremos']):
        return 'triste'
    elif any(palavra in fala_lower for palavra in ['?', 'o que', 'onde', 'como', 'sério', 'acredito', 'estranho', 'parece']):
        return 'surpreso'
    else:
        return 'neutro'

# Parseia os dados
entries = []
pattern = r'\((\d+):(\d+)\)\s*(.+?):\s*"(.+?)"'

matches = re.findall(pattern, dados)

for match in matches:
    minuto = int(match[0])
    segundo = int(match[1])
    personagem = match[2]
    fala = match[3]
    emocao = determinar_emocao(fala)
    entries.append({
        'personagem': personagem,
        'fala': fala,
        'emocao': emocao
    })

# Formata e imprime as falas com emoções
for entry in entries:
    print(f"{entry['personagem']}: \"{entry['fala']}\" ({entry['emocao']})")
# Out:
# Itadori: "Com tudo, sem hesitar!" (feliz)
# Nobara: "Tô um caco, mas quem liga?" (surpreso)
# Megumi: "Estratégia justa... nada mal." (neutro)
# Maki: "Sem vacilar agora, corre!" (feliz)
# Toge: "Salmon." (neutro)
# Gojo: "Brincar com a vovó, parece divertido." (surpreso)
# Itadori: "Não tava assustado! Talvez um pouco." (feliz)
# Nobara: "Enorme? Só uma velha insignificante." (surpreso)
# Megumi: "Mantenha a calma, sem pânico." (neutro)
# Maki: "Hora de fugir. Sem pensar duas vezes." (neutro)
# Toge: "Mostarda." (neutro)
# Gojo: "Confio, mostre do que é capaz." (feliz)
# Itadori: "Não sei se consigo, mas vou tentar!" (feliz)
# Nobara: "Sério? Não acredito que deu certo." (triste)
# Megumi: "Algo está errado, não vejo a maldição." (triste)
# Maki: "Não podemos baixar a guarda agora." (triste)
# Toge: "Kelp." (neutro)
# Gojo: "Provoca ele, ele vai cair." (neutro)
# Itadori: "Isso, mostre sua velocidade, vovó!" (feliz)
# Nobara: "Acha que pode me desafiar?" (surpreso)
# ...

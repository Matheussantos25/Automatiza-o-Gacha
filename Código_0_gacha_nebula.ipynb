# %% [markdown]
# Código final completo

# %%
import pyautogui 
import time
import random
import os
from PIL import ImageGrab
from pynput.keyboard import Listener as KeyboardListener, Key

# Variáveis globais para controlar a execução do código
rodando = True

# Coordenadas das setas para mudança de página
LEFT_ARROW_COORD = (1421, 648)
RIGHT_ARROW_COORD = (1566, 652)

# Função para parar a execução ao pressionar ESC
def on_press(key):
    global rodando
    if key == Key.esc:
        print("Execução interrompida pelo usuário (ESC).")
        rodando = False
        return False  # Para o listener de teclado

# Função para mover a janela do jogo
def mover_janela(jogo, x, y):
    windows = pyautogui.getWindowsWithTitle(jogo)
    if windows:
        windows[0].moveTo(x, y)
    else:
        print(f"Janela com título '{jogo}' não encontrada.")

# Função para capturar prints
def capturar_print(nome_arquivo, coordenadas):
    if not os.path.exists("./prints"):
        os.makedirs("./prints")
    imagem = ImageGrab.grab(bbox=coordenadas)
    imagem.save(f"./prints/{nome_arquivo}.png")

# Atualização das estruturas de dados com páginas
faces = {
    "feliz": [((1501, 330), 1), ((1576, 548), 1), ((1420, 277), 1), ((1511, 376), 1), ((1588, 379), 1)],
    "triste": [((1502, 539), 1), ((1415, 596), 2), ((1498, 540), 2)],
    "neutro": [((1428, 433), 1), ((1418, 478), 1), ((1581, 437), 1), ((1493, 275), 1), ((1506, 273), 2), ((1566, 280), 2)],
    "surpreso": [((1427, 276), 2), ((1422, 331), 2), ((1424, 588), 1), ((1423, 545), 1), ((1580, 489), 1)]
}

mouths = {
    "feliz": [((1422, 278), 1), ((1577, 283), 1), ((1419, 330), 1), ((1579, 433), 1), ((1584, 485), 2), ((1579, 537), 2), ((1496, 594), 2)],
    "triste": [((1502, 279), 1), ((1500, 328), 1), ((1416, 492), 1), ((1500, 441), 1), ((1569, 641), 2)],
    "neutro": [((1504, 543), 2), ((1588, 330), 2)],
    "boca_aberta_feliz": [((1584, 279), 3), ((1498, 333), 3), ((1414, 388), 3), ((1589, 374), 3), ((1422, 486), 3), ((1588, 486), 3), ((1428, 573), 3), ((1490, 382), 4), ((1434, 594), 4)],
    "boca_aberta_surpreso": [((1586, 331), 3), ((1405, 325), 3), ((1583, 424), 3)],
    "surpreso": [((1502, 330), 1), ((1420, 400), 1), ((1500, 460), 1)],
    "boca_aberta_neutro": [((1577, 435), 3), ((1576, 330), 3)],
    "boca_aberta_triste": [((1577, 435), 3), ((1576, 330), 3)]
}

# Lista de personagens com páginas atuais
personagens = [
    {"nome": "Itadori", "coordenada": (1659, 210), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Nobara", "coordenada": (1659, 259), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Megumi", "coordenada": (1661, 306), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Maki", "coordenada": (1660, 355), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Toge", "coordenada": (1657, 403), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Gojo", "coordenada": (1657, 450), "current_face_page": None, "current_mouth_page": None}
]

# Funções de reset e mudança de página
def reset_face_page(personagem):
    switch_face_page(personagem, 1)

def reset_mouth_page(personagem):
    switch_mouth_page(personagem, 1)

def switch_face_page(personagem, target_page):
    current_page = personagem['current_face_page'] or 1
    num_pages = 2

    if current_page == target_page:
        return

    forward_clicks = (target_page - current_page) % num_pages
    backward_clicks = (current_page - target_page) % num_pages

    if forward_clicks <= backward_clicks:
        for _ in range(forward_clicks):
            pyautogui.click(RIGHT_ARROW_COORD)
            time.sleep(0.2)
    else:
        for _ in range(backward_clicks):
            pyautogui.click(LEFT_ARROW_COORD)
            time.sleep(0.2)
    personagem['current_face_page'] = target_page
    time.sleep(0.5)

def switch_mouth_page(personagem, target_page):
    current_page = personagem['current_mouth_page'] or 1
    num_pages = 15

    if current_page == target_page:
        return

    forward_clicks = (target_page - current_page) % num_pages
    backward_clicks = (current_page - target_page) % num_pages

    if forward_clicks <= backward_clicks:
        for _ in range(forward_clicks):
            pyautogui.click(RIGHT_ARROW_COORD)
            time.sleep(0.1)
    else:
        for _ in range(backward_clicks):
            pyautogui.click(LEFT_ARROW_COORD)
            time.sleep(0.1)
    personagem['current_mouth_page'] = target_page
    time.sleep(0.5)

# Função para selecionar expressão facial e boca
def selecionar_face_mouth(personagem, emocao, boca_aberta=False):
    # Clicar no chat para iniciar a seleção da face
    pyautogui.click(1591, 351)  # Clicar em face

    # Resetar a página de face para 1
    reset_face_page(personagem)

    # Selecionar face
    face_options = faces.get(emocao, faces["neutro"])
    face_coord, face_page = random.choice(face_options)
    switch_face_page(personagem, face_page)
    pyautogui.click(face_coord)  # Clicar na face

    # Clicar no botão de seleção da boca
    pyautogui.click(1492, 653)

    # Resetar a página de boca para 1
    reset_mouth_page(personagem)

    # Selecionar boca
    if boca_aberta:
        mouth_key = f'boca_aberta_{emocao}'
        mouth_options = mouths.get(mouth_key, mouths.get(emocao, []))
    else:
        mouth_options = mouths.get(emocao, [])
    if not mouth_options:
        print(f"Nenhuma opção de boca encontrada para a emoção '{emocao}' com boca_aberta={boca_aberta}.")
        return
    mouth_coord, mouth_page = random.choice(mouth_options)
    switch_mouth_page(personagem, mouth_page)
    pyautogui.click(mouth_coord)  # Clicar na boca

# Função para processar cada personagem
def processar_personagem(personagem, emocao, boca_aberta=False):
    print(f"Processando personagem: {personagem['nome']} - Boca aberta: {boca_aberta}")

    # Verificar se o personagem é Itadori para clicar duas vezes
    if personagem['nome'] == "Itadori":
        print("Clicando duas vezes no Itadori...")
        pyautogui.click(personagem['coordenada'])
        pyautogui.click(personagem['coordenada'])
    else:
        pyautogui.click(personagem['coordenada'])

    # Selecionar face e boca
    selecionar_face_mouth(personagem, emocao, boca_aberta=boca_aberta)

    # Clicar duas vezes na área para confirmar
    pyautogui.click(1573, 217)
    pyautogui.click(1573, 217)

# Função para clicar no botão "view"
def clicar_view():
    print("Clicando no botão 'view'...")
    pyautogui.click(859, 631)  # Coordenada do botão "view"

# Função para processar todas as falas
def processar_falas(falas_emocoes):
    total_prints = 0
    max_prints = len(falas_emocoes)

    for fala_emocao in falas_emocoes:
        if not rodando:
            break

        personagem_fala = fala_emocao["personagem"]
        emocao = fala_emocao["emocao"]

        print(f"Processando fala: '{fala_emocao['fala']}' ({emocao}) - Personagem: {personagem_fala}")

        # Processar cada personagem
        for personagem in personagens:
            # Definir boca aberta apenas para o personagem da fala
            boca_aberta = personagem["nome"] == personagem_fala
            processar_personagem(personagem, emocao, boca_aberta)

        # Clicar no botão "view"
        clicar_view()

        # Capturar o print da área "view"
        capturar_print(f"print_view_{total_prints + 1}", (809, 184, 1703, 675))
        total_prints += 1

        if total_prints >= max_prints:
            break

# Ler falas do arquivo txt
def ler_falas(arquivo):
    falas_emocoes = []
    with open(arquivo, "r", encoding="utf-8") as f:
        for linha in f:
            linha = linha.strip()
            if not linha:
                continue  # Pular linhas vazias
            if ":" in linha and "(" in linha:
                personagem_part, resto = linha.split(":", 1)
                personagem = personagem_part.strip()
                fala_part, emocao_part = resto.rsplit("(", 1)
                fala = fala_part.strip()
                emocao = emocao_part.replace(")", "").strip()
                falas_emocoes.append({
                    "personagem": personagem,
                    "fala": fala,
                    "emocao": emocao
                })
    return falas_emocoes

# Função principal
def main():
    # Iniciar o listener do teclado para ESC
    with KeyboardListener(on_press=on_press) as listener:
        mover_janela("Gacha Nebula", 800, 150)

        # Esperar um pouco para garantir que a janela foi movida
        time.sleep(1)

        # Clicar na posição inicial, se necessário
        pyautogui.click(1390, 1060)

        falas_emocoes = ler_falas("falas.txt")
        processar_falas(falas_emocoes)

        listener.join()  # Espera o listener de teclado encerrar

if __name__ == "__main__":
    main()
# Out:
# Processando fala: 'Quem?' (feliz) - Personagem: Nobara
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: True
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Interessante.' (neutro) - Personagem: Megumi
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: True
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Vamos lá!' (feliz) - Personagem: Itadori
# Processando personagem: Itadori - Boca aberta: True
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Ótimo!' (feliz) - Personagem: Maki
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Execução interrompida pelo usuário (ESC).
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: True
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...

# %% [markdown]
# Código adaptado

# %%
import pyautogui  
import time
import random
import os
from PIL import ImageGrab
from pynput.keyboard import Listener as KeyboardListener, Key
import re
from datetime import timedelta

# Variáveis globais para controlar a execução do código
rodando = True

# Coordenadas das setas para mudança de página
LEFT_ARROW_COORD = (1421, 648)
RIGHT_ARROW_COORD = (1566, 652)

# Função para parar a execução ao pressionar ESC
def on_press(key):
    global rodando
    if key == Key.esc:
        print("Execução interrompida pelo usuário (ESC).")
        rodando = False
        return False  # Para o listener de teclado

# Função para mover a janela do jogo
def mover_janela(jogo, x, y):
    windows = pyautogui.getWindowsWithTitle(jogo)
    if windows:
        windows[0].moveTo(x, y)
    else:
        print(f"Janela com título '{jogo}' não encontrada.")

# Função para capturar prints
def capturar_print(nome_arquivo, coordenadas):
    if not os.path.exists("./prints"):
        os.makedirs("./prints")
    imagem = ImageGrab.grab(bbox=coordenadas)
    imagem.save(f"./prints/{nome_arquivo}.png")

# Atualização das estruturas de dados com páginas
faces = {
    "feliz": [((1501, 330), 1), ((1576, 548), 1), ((1420, 277), 1), ((1418, 328), 1), ((1412, 377), 1)],
    "triste": [((1502, 539), 1), ((1415, 596), 2), ((1498, 540), 2)],
    "neutro": [((1428, 433), 1), ((1418, 478), 1), ((1581, 437), 1), ((1493, 275), 1), ((1506, 273), 2), ((1566, 280), 2)],
    "surpreso": [((1427, 276), 2), ((1422, 331), 2), ((1424, 588), 1), ((1423, 545), 1), ((1580, 489), 1)]
}

mouths = {
    "feliz": [((1422, 278), 1), ((1577, 283), 1), ((1419, 330), 1), ((1579, 433), 1), ((1584, 485), 2), ((1579, 537), 2), ((1496, 594), 2)],
    "triste": [((1502, 279), 1), ((1500, 328), 1), ((1416, 492), 1), ((1500, 441), 1), ((1569, 641), 2)],
    "neutro": [((1504, 543), 2), ((1588, 330), 2)],
    "boca_aberta_feliz": [((1584, 279), 3), ((1498, 333), 3), ((1414, 388), 3), ((1589, 374), 3), ((1422, 486), 3), ((1588, 486), 3), ((1428, 573), 3), ((1490, 382), 4), ((1434, 594), 4)],
    "boca_aberta_surpreso": [((1586, 331), 3), ((1405, 325), 3), ((1583, 424), 3)],
    "surpreso": [((1502, 330), 1), ((1420, 400), 1), ((1500, 460), 1)],
    "boca_aberta_neutro": [((1577, 435), 3), ((1576, 330), 3)],
    "boca_aberta_triste": [((1577, 435), 3), ((1576, 330), 3)]
}

# Lista de personagens com páginas atuais
personagens = [
    {"nome": "Itadori", "coordenada": (1659, 210), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Nobara", "coordenada": (1659, 259), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Megumi", "coordenada": (1661, 306), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Maki", "coordenada": (1660, 355), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Toge", "coordenada": (1657, 403), "current_face_page": None, "current_mouth_page": None},
    {"nome": "Gojo", "coordenada": (1657, 450), "current_face_page": None, "current_mouth_page": None}
]

# Funções de reset e mudança de página
def reset_face_page(personagem):
    switch_face_page(personagem, 1)

def reset_mouth_page(personagem):
    switch_mouth_page(personagem, 1)

def switch_face_page(personagem, target_page):
    current_page = personagem['current_face_page'] or 1
    num_pages = 2

    if current_page == target_page:
        return

    forward_clicks = (target_page - current_page) % num_pages
    backward_clicks = (current_page - target_page) % num_pages

    if forward_clicks <= backward_clicks:
        for _ in range(forward_clicks):
            pyautogui.click(RIGHT_ARROW_COORD)
            time.sleep(0.2)
    else:
        for _ in range(backward_clicks):
            pyautogui.click(LEFT_ARROW_COORD)
            time.sleep(0.2)
    personagem['current_face_page'] = target_page
    time.sleep(0.5)

def switch_mouth_page(personagem, target_page):
    current_page = personagem['current_mouth_page'] or 1
    num_pages = 15

    if current_page == target_page:
        return

    forward_clicks = (target_page - current_page) % num_pages
    backward_clicks = (current_page - target_page) % num_pages

    if forward_clicks <= backward_clicks:
        for _ in range(forward_clicks):
            pyautogui.click(RIGHT_ARROW_COORD)
            time.sleep(0.1)
    else:
        for _ in range(backward_clicks):
            pyautogui.click(LEFT_ARROW_COORD)
            time.sleep(0.1)
    personagem['current_mouth_page'] = target_page
    time.sleep(0.5)

# Função para selecionar expressão facial e boca
def selecionar_face_mouth(personagem, face_emocao, mouth_emocao=None, boca_aberta=False):
    # Clicar no chat para iniciar a seleção da face
    pyautogui.click(1591, 351)  # Clicar em face

    # Resetar a página de face para 1
    reset_face_page(personagem)

    # Selecionar face
    face_options = faces.get(face_emocao, faces["neutro"])
    face_coord, face_page = random.choice(face_options)
    switch_face_page(personagem, face_page)
    pyautogui.click(face_coord)  # Clicar na face

    # Clicar no botão de seleção da boca
    pyautogui.click(1492, 653)

    # Resetar a página de boca para 1
    reset_mouth_page(personagem)

    # Selecionar boca
    if mouth_emocao is None:
        mouth_emocao = face_emocao

    if boca_aberta:
        mouth_key = f'boca_aberta_{mouth_emocao}'
        mouth_options = mouths.get(mouth_key, mouths.get(mouth_emocao, []))
    else:
        mouth_options = mouths.get(mouth_emocao, [])
    if not mouth_options:
        print(f"Nenhuma opção de boca encontrada para a emoção '{mouth_emocao}' com boca_aberta={boca_aberta}.")
        return
    mouth_coord, mouth_page = random.choice(mouth_options)
    switch_mouth_page(personagem, mouth_page)
    pyautogui.click(mouth_coord)  # Clicar na boca

# Função para processar cada personagem
def processar_personagem(personagem, face_emocao, mouth_emocao=None, boca_aberta=False):
    print(f"Processando personagem: {personagem['nome']} - Boca aberta: {boca_aberta}")

    # Verificar se o personagem é Itadori para clicar duas vezes
    if personagem['nome'] == "Itadori":
        print("Clicando duas vezes no Itadori...")
        pyautogui.click(personagem['coordenada'])
        pyautogui.click(personagem['coordenada'])
    else:
        pyautogui.click(personagem['coordenada'])

    # Selecionar face e boca
    selecionar_face_mouth(personagem, face_emocao, mouth_emocao, boca_aberta)

    # Clicar duas vezes na área para confirmar
    pyautogui.click(1573, 217)
    pyautogui.click(1573, 217)

# Função para clicar no botão "view"
def clicar_view():
    print("Clicando no botão 'view'...")
    pyautogui.click(859, 631)  # Coordenada do botão "view"

# Função para processar a linha do tempo
def processar_timeline(timeline, dialogues):
    dialogue_index = 0
    dialogue_count = len(dialogues)

    total_prints = 0
    max_prints = len(timeline)

    for timestamp in timeline:
        if not rodando:
            break

        # Verificar se há um diálogo neste timestamp
        if dialogue_index < dialogue_count and timestamp >= dialogues[dialogue_index]['start_time']:
            # Existe um diálogo neste momento
            dialogue = dialogues[dialogue_index]
            print(f"Processando fala: '{dialogue['fala']}' ({dialogue['emocao']}) - Personagem: {dialogue['personagem']} - Tempo: {timestamp}")

            # Processar cada personagem
            for personagem in personagens:
                # Definir boca aberta apenas para o personagem da fala
                boca_aberta = personagem["nome"] == dialogue['personagem']
                processar_personagem(personagem, dialogue['emocao'], boca_aberta=boca_aberta)

            dialogue_index += 1
        else:
            # Sem diálogo neste momento, ação padrão
            print(f"Processando ação padrão - Tempo: {timestamp}")

            # Processar cada personagem com face feliz e boca feliz ou neutra
            for personagem in personagens:
                mouth_emocao = random.choice(['feliz', 'neutro'])
                processar_personagem(personagem, 'feliz', mouth_emocao=mouth_emocao, boca_aberta=False)

        # Clicar no botão "view"
        clicar_view()

        # Capturar o print da área "view"
        capturar_print(f"print_view_{total_prints + 1}", (809, 184, 1703, 675))
        total_prints += 1

# Ler diálogos com timestamps e emoções
def ler_dialogues(arquivo_falas, arquivo_legendas):
    # Ler falas.txt
    falas = []
    with open(arquivo_falas, "r", encoding="utf-8") as f:
        for linha in f:
            linha = linha.strip()
            if not linha:
                continue
            m = re.match(r'(.+?):\s*(.+?)\s*\((.+?)\)', linha)
            if m:
                personagem = m.group(1)
                fala = m.group(2)
                emocao = m.group(3)
                falas.append({
                    'personagem': personagem,
                    'fala': fala,
                    'emocao': emocao
                })

    # Ler legendas.srt
    with open(arquivo_legendas, "r", encoding="utf-8") as f:
        data = f.read()

    pattern = r'\d+\s+(\d+):(\d+):(\d+),\d+\s+-->\s+(\d+):(\d+):(\d+),\d+\s+(.+?):\s*"(.+?)"'
    matches = re.findall(pattern, data)

    dialogues = []
    for i, match in enumerate(matches):
        start_hour = int(match[0])
        start_minute = int(match[1])
        start_second = int(match[2])
        end_hour = int(match[3])
        end_minute = int(match[4])
        end_second = int(match[5])
        personagem = match[6]
        fala = match[7]
        start_time = timedelta(hours=start_hour, minutes=start_minute, seconds=start_second)
        end_time = timedelta(hours=end_hour, minutes=end_minute, seconds=end_second)
        dialogues.append({
            'start_time': start_time,
            'end_time': end_time,
            'personagem': personagem,
            'fala': fala
        })

    # Combinar falas com dialogues
    for i in range(len(dialogues)):
        if i < len(falas):
            dialogues[i]['emocao'] = falas[i]['emocao']
        else:
            dialogues[i]['emocao'] = 'feliz'  # Definir emoção 'feliz' se não houver correspondência

    return dialogues

# Função principal
def main():
    # Iniciar o listener do teclado para ESC
    with KeyboardListener(on_press=on_press) as listener:
        mover_janela("Gacha Nebula", 800, 150)

        # Esperar um pouco para garantir que a janela foi movida
        time.sleep(1)

        # Clicar na posição inicial, se necessário
        pyautogui.click(1390, 1060)

        # Gerar linha do tempo de 5 em 5 segundos
        total_duration_seconds = 22 * 60  # 1320 segundos
        interval = 5  # segundos
        timeline = [timedelta(seconds=i) for i in range(0, total_duration_seconds + 1, interval)]

        # Ler diálogos com timestamps e emoções
        dialogues = ler_dialogues("falas.txt", "legendas.srt")

        processar_timeline(timeline, dialogues)

        listener.join()  # Espera o listener de teclado encerrar

if __name__ == "__main__":
    main()
# Out:
# Processando ação padrão - Tempo: 0:00:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:00:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Com tudo, sem hesitar!' (neutro) - Personagem: Itadori - Tempo: 0:00:10
# Processando personagem: Itadori - Boca aberta: True
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Tô um caco, mas quem liga?' (neutro) - Personagem: Nobara - Tempo: 0:00:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: True
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:00:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:00:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Estratégia justa... nada mal.' (feliz) - Personagem: Megumi - Tempo: 0:00:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: True
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:00:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:00:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:00:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Sem vacilar agora, corre!' (feliz) - Personagem: Maki - Tempo: 0:00:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: True
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:00:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:01:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Salmon.' (neutro) - Personagem: Toge - Tempo: 0:01:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: True
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:01:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:01:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:01:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Brincar com a vovó, parece divertido.' (neutro) - Personagem: Gojo - Tempo: 0:01:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: True
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:01:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:01:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Não tava assustado! Talvez um pouco.' (neutro) - Personagem: Itadori - Tempo: 0:01:40
# Processando personagem: Itadori - Boca aberta: True
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:01:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:01:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:01:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Enorme? Só uma velha insignificante.' (neutro) - Personagem: Nobara - Tempo: 0:02:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: True
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:02:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:02:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Mantenha a calma, sem pânico.' (neutro) - Personagem: Megumi - Tempo: 0:02:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: True
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:02:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:02:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:02:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Hora de fugir. Sem pensar duas vezes.' (neutro) - Personagem: Maki - Tempo: 0:02:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: True
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:02:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:02:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Mostarda.' (neutro) - Personagem: Toge - Tempo: 0:02:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: True
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:02:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:03:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:03:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Confio, mostre do que é capaz.' (neutro) - Personagem: Gojo - Tempo: 0:03:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: True
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:03:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:03:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Não sei se consigo, mas vou tentar!' (neutro) - Personagem: Itadori - Tempo: 0:03:25
# Processando personagem: Itadori - Boca aberta: True
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:03:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:03:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:03:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Sério? Não acredito que deu certo.' (surpreso) - Personagem: Nobara - Tempo: 0:03:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: True
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:03:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:03:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Algo está errado, não vejo a maldição.' (neutro) - Personagem: Megumi - Tempo: 0:04:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: True
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:04:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:04:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:04:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Não podemos baixar a guarda agora.' (neutro) - Personagem: Maki - Tempo: 0:04:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: True
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:04:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:04:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Kelp.' (neutro) - Personagem: Toge - Tempo: 0:04:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: True
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:04:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:04:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:04:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Provoca ela, ela vai cair.' (neutro) - Personagem: Gojo - Tempo: 0:04:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: True
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:05:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:05:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Isso, mostre sua velocidade, vovó!' (feliz) - Personagem: Itadori - Tempo: 0:05:10
# Processando personagem: Itadori - Boca aberta: True
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:05:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:05:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:05:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Acha que pode me desafiar?' (neutro) - Personagem: Nobara - Tempo: 0:05:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: True
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:05:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:05:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Vamos brincar de pega-pega, é isso.' (neutro) - Personagem: Megumi - Tempo: 0:05:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: True
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:05:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:05:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:06:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Essas são as regras, siga-as.' (neutro) - Personagem: Maki - Tempo: 0:06:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: True
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:06:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:06:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Atum.' (neutro) - Personagem: Toge - Tempo: 0:06:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: True
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:06:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:06:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:06:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Contou errado! Que graça.' (feliz) - Personagem: Gojo - Tempo: 0:06:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: True
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:06:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:06:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Ayase, aguenta aí!' (neutro) - Personagem: Itadori - Tempo: 0:06:55
# Processando personagem: Itadori - Boca aberta: True
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:07:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:07:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:07:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Isso é trapaça, não vale!' (neutro) - Personagem: Nobara - Tempo: 0:07:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: True
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:07:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:07:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Prometeu seguir as regras.' (neutro) - Personagem: Megumi - Tempo: 0:07:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: True
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:07:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:07:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:07:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Chega dessa palhaçada!' (neutro) - Personagem: Maki - Tempo: 0:07:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: True
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:07:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:08:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Maionese.' (neutro) - Personagem: Toge - Tempo: 0:08:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: True
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:08:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:08:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:08:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Garoto, segura firme aí.' (neutro) - Personagem: Gojo - Tempo: 0:08:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: True
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:08:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:08:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'A purificação funcionou? Ainda não acredito.' (surpreso) - Personagem: Itadori - Tempo: 0:08:40
# Processando personagem: Itadori - Boca aberta: True
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:08:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:08:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:08:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Tá em contato com xamãs? Patético.' (neutro) - Personagem: Nobara - Tempo: 0:09:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: True
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:09:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:09:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Essa sensação... algo estranho.' (neutro) - Personagem: Megumi - Tempo: 0:09:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: True
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:09:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# ...
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:19:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:19:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Ayase, onde estamos?' (neutro) - Personagem: Itadori - Tempo: 0:19:10
# Processando personagem: Itadori - Boca aberta: True
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:19:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:19:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Elas não mereciam esse destino.' (triste) - Personagem: Nobara - Tempo: 0:19:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: True
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:19:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:19:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:19:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Tentando confortar as almas.' (neutro) - Personagem: Megumi - Tempo: 0:19:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: True
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:19:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:19:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Nunca desrespeite os mortos.' (neutro) - Personagem: Maki - Tempo: 0:20:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: True
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:20:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:20:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Umeboshi.' (neutro) - Personagem: Toge - Tempo: 0:20:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: True
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:20:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:20:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:20:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Este lugar é mais seguro, confiem.' (neutro) - Personagem: Gojo - Tempo: 0:20:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: True
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:20:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:20:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Não vou mostrar nada, esqueça.' (neutro) - Personagem: Itadori - Tempo: 0:20:50
# Processando personagem: Itadori - Boca aberta: True
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:20:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:05
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Desculpa, não queria causar.' (triste) - Personagem: Nobara - Tempo: 0:21:10
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: True
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:15
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:20
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando fala: 'Adeus, até breve.' (neutro) - Personagem: Megumi - Tempo: 0:21:25
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: True
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:30
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:35
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:40
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:45
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:50
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:21:55
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...
# Processando ação padrão - Tempo: 0:22:00
# Processando personagem: Itadori - Boca aberta: False
# Clicando duas vezes no Itadori...
# Processando personagem: Nobara - Boca aberta: False
# Processando personagem: Megumi - Boca aberta: False
# Processando personagem: Maki - Boca aberta: False
# Processando personagem: Toge - Boca aberta: False
# Processando personagem: Gojo - Boca aberta: False
# Clicando no botão 'view'...

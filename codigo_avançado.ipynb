# %% [markdown]
# Código final ajustado, com: \
#
# Time stamp para organização da sequência de falas dos personagens \
# Screen shots salvas numa pasta só (evitando muitos prints pro vscode não ficar poluído) \

# %%
import pyautogui
import time
import random
import os
from PIL import ImageGrab
from pynput.keyboard import Listener as KeyboardListener, Key

# Variável global para controlar a execução do código
rodando = True

# Função para parar a execução ao pressionar ESC
def on_press(key):
    global rodando
    if key == Key.esc:
        print("Execução interrompida pelo usuário (ESC).")
        rodando = False
        return False  # Para o listener de teclado

# Função para mover a janela do jogo
def mover_janela(jogo, x, y):
    pyautogui.getWindowsWithTitle(jogo)[0].moveTo(x, y)

# Função para capturar prints
def capturar_print(nome_arquivo, coordenadas):
    if not os.path.exists("./prints"):
        os.makedirs("./prints")
    imagem = ImageGrab.grab(bbox=coordenadas)
    imagem.save(f"./prints/{nome_arquivo}.png")

# Função para escolher uma expressão facial e movimento de boca com base na emoção
def selecionar_face_mouth(emocao):
    faces = {
        "feliz": [(1501, 330), (1576, 548), (1420, 277), (1511, 376), (1588, 379)],
        "triste": [(1502, 539), (1415, 596), (1498, 540)],
        "neutro": [(1428, 433), (1418, 478), (1581, 437), (1493, 275), (1506, 273), (1566, 280)],
        "surpreso": [(1427, 276), (1422, 331), (1424, 588), (1423, 545), (1580, 489)]
    }
    
    mouths = {
        "feliz": [(1422, 278), (1577, 283), (1419, 330), (1579, 433), (1584, 485), (1579, 537), (1496, 594)],
        "triste": [(1502, 279), (1500, 328), (1416, 492), (1500, 441), (1569, 641)],
        "neutro": [(1504, 543), (1588, 330)],
        "boca_aberta_feliz": [(1584, 279), (1498, 333), (1414, 388), (1589, 374), (1422, 486), (1588, 486), (1428, 573)],
        "boca_aberta_surpreso": [(1586, 331), (1405, 325), (1583, 424)]
    }
    
    face_coord = random.choice(faces[emocao])
    
    if "boca_aberta" in emocao:
        mouth_coord = random.choice(mouths[emocao])
    else:
        mouth_coord = random.choice(mouths[emocao])
    
    return face_coord, mouth_coord

# Função para processar cada personagem
def processar_personagem(personagem, coordenada_personagem, fala_emocao):
    pyautogui.click(coordenada_personagem)
    time.sleep(1)
    
    fala, emocao = fala_emocao
    
    pyautogui.click(1591, 351)
    time.sleep(1)
    
    face_coord, mouth_coord = selecionar_face_mouth(emocao)
    
    pyautogui.click(face_coord)
    time.sleep(1)
    
    pyautogui.click(1492, 653)
    time.sleep(0.5)
    pyautogui.click(mouth_coord)
    time.sleep(1)
    
    if "boca_aberta" in emocao:
        pyautogui.click(1595, 279)
        pyautogui.write(fala)
        pyautogui.click(1437, 398)
        time.sleep(1)
    
    pyautogui.click(1573, 217)
    time.sleep(1)

# Função principal para processar todos os personagens
def processar_falas(falas_emocoes):
    personagens = [
        {"nome": "Itadori", "coordenada": (1659, 210)},
        {"nome": "Nobara", "coordenada": (1659, 259)},
        {"nome": "Megumi", "coordenada": (1661, 306)},
        {"nome": "Maki", "coordenada": (1660, 355)},
        {"nome": "Toge", "coordenada": (1657, 403)},
        {"nome": "Gojo", "coordenada": (1657, 450)}
    ]
    
    for i, fala_emocao in enumerate(falas_emocoes):
        if not rodando:  # Checa se a execução foi interrompida
            break
        personagem = personagens[i % len(personagens)]
        processar_personagem(personagem["nome"], personagem["coordenada"], fala_emocao)
        
        pyautogui.click(859, 631)
        time.sleep(1)
        
        capturar_print(f"print_{personagem['nome']}_{int(time.time())}", (809, 184, 1703, 675))
        time.sleep(1)

# Ler falas do arquivo txt
def ler_falas(arquivo):
    falas_emocoes = []
    with open(arquivo, "r") as f:
        for linha in f:
            fala, emocao = linha.rsplit("(", 1)
            emocao = emocao.replace(")", "").replace("\"", "").strip()
            falas_emocoes.append((fala.strip(), emocao))
    return falas_emocoes

# Função principal
def main():
    # Iniciar o listener do teclado para ESC
    with KeyboardListener(on_press=on_press) as listener:
        mover_janela("Gacha Nebula", 800, 150)
        time.sleep(2)

        pyautogui.click(1390, 1060)
        time.sleep(2)

        falas_emocoes = ler_falas("falas.txt")
        processar_falas(falas_emocoes)

        listener.join()  # Espera o listener de teclado encerrar

if __name__ == "__main__":
    main()
# Out:
# Execução interrompida pelo usuário (ESC).

# %% [markdown]
# Testando coisas

# %%
import pyautogui 
import time
import random
import os
from PIL import ImageGrab
from pynput.keyboard import Listener as KeyboardListener, Key

# Variável global para controlar a execução do código
rodando = True

# Função para parar a execução ao pressionar ESC
def on_press(key):
    global rodando
    if key == Key.esc:
        print("Execução interrompida pelo usuário (ESC).")
        rodando = False
        return False  # Para o listener de teclado

# Função para mover a janela do jogo
def mover_janela(jogo, x, y):
    pyautogui.getWindowsWithTitle(jogo)[0].moveTo(x, y)

# Função para capturar prints
def capturar_print(nome_arquivo, coordenadas):
    if not os.path.exists("./prints"):
        os.makedirs("./prints")
    imagem = ImageGrab.grab(bbox=coordenadas)
    imagem.save(f"./prints/{nome_arquivo}.png")

# Função para escolher uma expressão facial e movimento de boca com base na emoção
def selecionar_face_mouth(emocao):
    faces = {
        "feliz": [(1501, 330), (1576, 548), (1420, 277), (1511, 376), (1588, 379)],
        "triste": [(1502, 539), (1415, 596), (1498, 540)],
        "neutro": [(1428, 433), (1418, 478), (1581, 437), (1493, 275), (1506, 273), (1566, 280)],
        "surpreso": [(1427, 276), (1422, 331), (1424, 588), (1423, 545), (1580, 489)]
    }
    
    mouths = {
        "feliz": [(1422, 278), (1577, 283), (1419, 330), (1579, 433), (1584, 485), (1579, 537), (1496, 594)],
        "triste": [(1502, 279), (1500, 328), (1416, 492), (1500, 441), (1569, 641)],
        "neutro": [(1504, 543), (1588, 330)],
        "boca_aberta_feliz": [(1584, 279), (1498, 333), (1414, 388), (1589, 374), (1422, 486), (1588, 486), (1428, 573)],
        "boca_aberta_surpreso": [(1586, 331), (1405, 325), (1583, 424)]
    }
    
    face_coord = random.choice(faces[emocao])
    
    if "boca_aberta" in emocao:
        mouth_coord = random.choice(mouths[emocao])
    else:
        mouth_coord = random.choice(mouths[emocao])
    
    return face_coord, mouth_coord

# Função para processar cada personagem
def processar_personagem(personagem, coordenada_personagem, fala_emocao):
    print(f"Processando personagem: {personagem}")
    
    # Clicar no personagem
    pyautogui.click(coordenada_personagem)
    time.sleep(1)
    
    fala, emocao = fala_emocao
    
    # Clicar para abrir o chat (certifique-se que esta coordenada está correta)
    print("Clicando no chat...")
    pyautogui.click(1591, 351)  # Coordenada do chat
    time.sleep(1)
    
    # Selecionar face e boca com base na emoção
    face_coord, mouth_coord = selecionar_face_mouth(emocao)
    
    # Clicar no local da face
    print(f"Clicando na face: {face_coord}")
    pyautogui.click(face_coord)
    time.sleep(1)
    
    # Clicar na boca
    print(f"Clicando na boca: {mouth_coord}")
    pyautogui.click(1492, 653)  # Coordenada para abrir menu da boca
    time.sleep(0.5)
    pyautogui.click(mouth_coord)
    time.sleep(1)
    
    # Verificar se a fala tem boca aberta
    if "boca_aberta" in emocao:
        pyautogui.click(1595, 279)  # Clicar na área para inserir o texto
        print(f"Escrevendo fala: {fala}")
        pyautogui.write(fala)  # Escrever a fala no chat
        pyautogui.click(1437, 398)  # Enviar a mensagem
        time.sleep(1)
    
    # Clicar na área "view" (Certifique-se de que a coordenada está correta)
    print("Clicando na view (1573, 217)...")
    pyautogui.click(1573, 217)
    time.sleep(1)

# Função principal para processar todos os personagens
def processar_falas(falas_emocoes):
    personagens = [
        {"nome": "Itadori", "coordenada": (1659, 210)},
        {"nome": "Nobara", "coordenada": (1659, 259)},
        {"nome": "Megumi", "coordenada": (1661, 306)},
        {"nome": "Maki", "coordenada": (1660, 355)},
        {"nome": "Toge", "coordenada": (1657, 403)},
        {"nome": "Gojo", "coordenada": (1657, 450)}
    ]
    
    for i, fala_emocao in enumerate(falas_emocoes):
        if not rodando:  # Checa se a execução foi interrompida
            break
        personagem = personagens[i % len(personagens)]
        processar_personagem(personagem["nome"], personagem["coordenada"], fala_emocao)
        
        # Clicar em algum ponto depois de processar (Certifique-se que está correto)
        pyautogui.click(859, 631)
        time.sleep(1)
        
        # Tirar o print da tela
        capturar_print(f"print_{personagem['nome']}_{int(time.time())}", (809, 184, 1703, 675))
        time.sleep(1)

# Ler falas do arquivo txt
def ler_falas(arquivo):
    falas_emocoes = []
    with open(arquivo, "r") as f:
        for linha in f:
            fala, emocao = linha.rsplit("(", 1)
            emocao = emocao.replace(")", "").replace("\"", "").strip()
            falas_emocoes.append((fala.strip(), emocao))
    return falas_emocoes

# Função principal
def main():
    # Iniciar o listener do teclado para ESC
    with KeyboardListener(on_press=on_press) as listener:
        mover_janela("Gacha Nebula", 800, 150)
        time.sleep(2)

        pyautogui.click(1390, 1060)
        time.sleep(2)

        falas_emocoes = ler_falas("falas.txt")
        processar_falas(falas_emocoes)

        listener.join()  # Espera o listener de teclado encerrar

if __name__ == "__main__":
    main()
# Out:
# Processando personagem: Itadori
# Clicando no chat...
# Clicando na face: (1501, 330)
# Clicando na boca: (1579, 433)
# Clicando na view (1573, 217)...
# Processando personagem: Nobara
# Clicando no chat...
# Clicando na face: (1498, 540)
# Execução interrompida pelo usuário (ESC).
# Clicando na boca: (1500, 441)
# Clicando na view (1573, 217)...

# %% [markdown]
# Teste chat

# %%
import pyautogui
import time

# Coordenadas dos personagens na sequência correta
personagens = [
    {"nome": "Itadori", "coordenada": (1659, 210)},
    {"nome": "Nobara", "coordenada": (1659, 259)},
    {"nome": "Megumi", "coordenada": (1661, 306)},
    {"nome": "Maki", "coordenada": (1660, 355)},
    {"nome": "Toge", "coordenada": (1657, 403)},
    {"nome": "Gojo", "coordenada": (1657, 450)}
]

# Função para focar a janela do jogo (substitua "Gacha Nebula" pelo nome da janela do seu jogo)
def focar_janela(jogo):
    janela = pyautogui.getWindowsWithTitle(jogo)[0]
    janela.activate()  # Ativa a janela
    time.sleep(1)  # Pausa para garantir que a janela foi focada

# Função para clicar no chat, inserir a frase, sair do chat e clicar em view
def processar_falas_chat(personagens, falas_emocoes):
    for i, personagem in enumerate(personagens):
        fala, emocao = falas_emocoes[i]  # Pegar a fala correspondente ao personagem atual
        print(f"Processando personagem: {personagem['nome']} com fala: {fala} (Emoção: {emocao})")
        
        # Clicar no personagem
        pyautogui.click(personagem['coordenada'])
        time.sleep(2)  # Pausa para dar tempo de processar o clique

        # Clicar para abrir o chat
        pyautogui.click(1595, 288)  # Coordenada do chat
        time.sleep(2)  # Pausa para garantir que o chat abriu
        
        # Escrever a fala no chat
        print(f"Escrevendo a frase: {fala}")
        pyautogui.write(fala)
        time.sleep(1)
        
        # Fechar o chat
        pyautogui.click(1437, 398)  # Coordenada para fechar o chat
        time.sleep(1)
        
        # Clicar na área "view"
        pyautogui.click(859, 631)
        time.sleep(2)  # Pausa para garantir que a ação foi processadaGojo: "Isso eh decepcionante..."

# Função para ler falas do arquivo txt
def ler_falas(arquivo):
    falas_emocoes = []
    with open(arquivo, "r") as f:
        for linha in f:
            fala, emocao = linha.rsplit("(", 1)
            emocao = emocao.replace(")", "").replace("\"", "").strip()
            falas_emocoes.append((fala.strip(), emocao))
    return falas_emocoes

# Função principal
def main():
    # Focar a janela do jogo
    focar_janela("Gacha Nebula")  # Substitua "Gacha Nebula" pelo nome da janela do seu jogo
    
    # Ler as falas do arquivo txtItadori: "Estou muito animado hoje!"
    falas_emocoes = ler_falas("falas.txt")
    
    # Processar cada fala no chat
    processar_falas_chat(personagens, falas_emocoes)

if __name__ == "__main__":
    main()
# Out:
# Processando personagem: Itadori com fala: Itadori: "Estou muito animado hoje! (Emoção: feliz)
# Escrevendo a frase: Itadori: "Estou muito animado hoje!
# Processando personagem: Nobara com fala: Gojo: "Isso eh decepcionante... (Emoção: triste)
# Escrevendo a frase: Gojo: "Isso eh decepcionante...
# Processando personagem: Megumi com fala: Nobara:"Nem bom, nem ruim. (Emoção: neutro)
# Escrevendo a frase: Nobara:"Nem bom, nem ruim.
# Processando personagem: Maki com fala: Megumi: "Uau! Isso foi incrivel! (Emoção: surpreso)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 69
#      66     processar_falas_chat(personagens, falas_emocoes)
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# Cell In[20], line 66, in main()
#      63 falas_emocoes = ler_falas("falas.txt")
#      65 # Processar cada fala no chat
# ---> 66 processar_falas_chat(personagens, falas_emocoes)
#
# Cell In[20], line 32, in processar_falas_chat(personagens, falas_emocoes)
#      30 # Clicar para abrir o chat
#      31 pyautogui.click(1595, 288)  # Coordenada do chat
# ---> 32 time.sleep(2)  # Pausa para garantir que o chat abriu
#      34 # Escrever a fala no chat
#      35 print(f"Escrevendo a frase: {fala}")
#
# KeyboardInterrupt:

# %% [markdown]
# Versão completa?

# %%
import pyautogui
import time
import random
import os
from PIL import ImageGrab
from pynput.keyboard import Listener as KeyboardListener, Key

# Variável global para controlar a execução do código
rodando = True

# Função para parar a execução ao pressionar ESC
def on_press(key):
    global rodando
    if key == Key.esc:
        print("Execução interrompida pelo usuário (ESC).")
        rodando = False
        return False  # Para o listener de teclado

# Função para mover a janela do jogo
def mover_janela(jogo, x, y):
    pyautogui.getWindowsWithTitle(jogo)[0].moveTo(x, y)

# Função para capturar prints
def capturar_print(nome_arquivo, coordenadas):
    if not os.path.exists("./prints"):
        os.makedirs("./prints")
    imagem = ImageGrab.grab(bbox=coordenadas)
    imagem.save(f"./prints/{nome_arquivo}.png")

# Função para escolher uma expressão facial e movimento de boca com base na emoção
def selecionar_face_mouth(emocao):
    faces = {
        "feliz": [(1501, 330), (1576, 548), (1420, 277), (1511, 376), (1588, 379)],
        "triste": [(1502, 539), (1415, 596), (1498, 540)],
        "neutro": [(1428, 433), (1418, 478), (1581, 437), (1493, 275), (1506, 273), (1566, 280)],
        "surpreso": [(1427, 276), (1422, 331), (1424, 588), (1423, 545), (1580, 489)]
    }
    
    mouths = {
        "feliz": [(1422, 278), (1577, 283), (1419, 330), (1579, 433), (1584, 485), (1579, 537), (1496, 594)],
        "triste": [(1502, 279), (1500, 328), (1416, 492), (1500, 441), (1569, 641)],
        "neutro": [(1504, 543), (1588, 330)],
        "boca_aberta_feliz": [(1584, 279), (1498, 333), (1414, 388), (1589, 374), (1422, 486), (1588, 486), (1428, 573)],
        "boca_aberta_surpreso": [(1586, 331), (1405, 325), (1583, 424)]
    }
    
    face_coord = random.choice(faces[emocao])
    
    if "boca_aberta" in emocao:
        mouth_coord = random.choice(mouths[emocao])
    else:
        mouth_coord = random.choice(mouths[emocao])
    
    return face_coord, mouth_coord

# Função para processar cada personagem
def processar_personagem(personagem, coordenada_personagem, fala_emocao):
    print(f"Processando personagem: {personagem}")
    
    # Clicar no personagem
    pyautogui.click(coordenada_personagem)
    time.sleep(1)
    
    fala, emocao = fala_emocao
    
    # Clicar para abrir o chat (certifique-se que esta coordenada está correta)
    print("Clicando no chat...")
    pyautogui.click(1595, 288)  # Coordenada do chat
    time.sleep(1)
    
    # Selecionar face e boca com base na emoção
    face_coord, mouth_coord = selecionar_face_mouth(emocao)
    
    # Clicar no local da face
    print(f"Clicando na face: {face_coord}")
    pyautogui.click(face_coord)
    time.sleep(1)
    
    # Clicar na boca
    print(f"Clicando na boca: {mouth_coord}")
    pyautogui.click(1492, 653)  # Coordenada para abrir menu da boca
    time.sleep(0.5)
    pyautogui.click(mouth_coord)
    time.sleep(1)
    
    # Verificar se a fala tem boca aberta
    if "boca_aberta" in emocao:
        pyautogui.click(1595, 279)  # Clicar na área para inserir o texto
        print(f"Escrevendo fala: {fala}")
        pyautogui.write(fala)  # Escrever a fala no chat
        pyautogui.click(1437, 398)  # Enviar a mensagem
        time.sleep(1)
    
    # Clicar na área "view" para fechar o preset
    print("Clicando na área para fechar (1573, 217)...")
    pyautogui.click(1573, 217)
    time.sleep(1)

# Função principal para processar todos os personagens
def processar_falas(falas_emocoes):
    personagens = [
        {"nome": "Itadori", "coordenada": (1659, 210)},
        {"nome": "Nobara", "coordenada": (1659, 259)},
        {"nome": "Megumi", "coordenada": (1661, 306)},
        {"nome": "Maki", "coordenada": (1660, 355)},
        {"nome": "Toge", "coordenada": (1657, 403)},
        {"nome": "Gojo", "coordenada": (1657, 450)}
    ]
    
    for i, fala_emocao in enumerate(falas_emocoes):
        if not rodando:  # Checa se a execução foi interrompida
            break
        personagem = personagens[i % len(personagens)]
        processar_personagem(personagem["nome"], personagem["coordenada"], fala_emocao)
        
        # Clicar em algum ponto depois de processar (Certifique-se que está correto)
        pyautogui.click(859, 631)
        time.sleep(1)
        
        # Tirar o print da tela
        capturar_print(f"print_{personagem['nome']}_{int(time.time())}", (809, 184, 1703, 675))
        time.sleep(1)

# Ler falas do arquivo txt
def ler_falas(arquivo):
    falas_emocoes = []
    with open(arquivo, "r") as f:
        for linha in f:
            fala, emocao = linha.rsplit("(", 1)
            emocao = emocao.replace(")", "").replace("\"", "").strip()
            falas_emocoes.append((fala.strip(), emocao))
    return falas_emocoes

# Função principal
def main():
    # Iniciar o listener do teclado para ESC
    with KeyboardListener(on_press=on_press) as listener:
        mover_janela("Gacha Nebula", 800, 150)
        time.sleep(2)

        pyautogui.click(1390, 1060)
        time.sleep(2)

        falas_emocoes = ler_falas("falas.txt")
        processar_falas(falas_emocoes)

        listener.join()  # Espera o listener de teclado encerrar

if __name__ == "__main__":
    main()
# Out:
# Processando personagem: Itadori
# Clicando no chat...
# Clicando na face: (1576, 548)
# Clicando na boca: (1579, 433)
# Clicando na área para fechar (1573, 217)...
# Execução interrompida pelo usuário (ESC).
